# %%
import pandas as pd
matches= pd.read_csv("matches.csv")
deliveries= pd.read_csv("deliveries.csv")

matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
#i.Matches won by the maximum margin of runs
matches.loc[matches['win_by_runs'].idxmax()]
# Out:
# id                               44
# season                         2017
# city                          Delhi
# date                     2017-05-06
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# umpire3                         NaN
# Name: 43, dtype: object

# %%
#INSIGHT
.Winning team scored much higher runs
.winning toss winner by team2(Delhi Daredevils)
.Winner match Mumbai Indians
.The losing team could not compete well

# %%
#ii.Match won by maximum wickets
matches.loc[matches['win_by_wickets'].idxmax()]
# Out:
# id                                                      3
# season                                               2017
# city                                               Rajkot
# date                                           2017-04-07
# team1                                       Gujarat Lions
# team2                               Kolkata Knight Riders
# toss_winner                         Kolkata Knight Riders
# toss_decision                                       field
# result                                             normal
# dl_applied                                              0
# winner                              Kolkata Knight Riders
# win_by_runs                                             0
# win_by_wickets                                         10
# player_of_match                                   CA Lynn
# venue              Saurashtra Cricket Association Stadium
# umpire1                                       Nitin Menon
# ...

# %%
#INSIGHT
.Toss winner by kolkata knight riders
.Winner by wickets 10 for gujarat lions
.This shows strong batting performance

# %%
import pandas as pd
matches= pd.read_csv("matches.csv")
deliveries= pd.read_csv("deliveries.csv")

matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
#iii. Matches won by minimum margin of runs
min_run_win=matches[matches['win_by_runs']>
    0].sort_values(by='win_by_runs').iloc[0]
min_run_win
# Out:
# id                                              11415
# season                                           2019
# city                                        Hyderabad
# date                                         12/05/19
# team1                                  Mumbai Indians
# team2                             Chennai Super Kings
# toss_winner                            Mumbai Indians
# toss_decision                                     bat
# result                                         normal
# dl_applied                                          0
# winner                                 Mumbai Indians
# win_by_runs                                         1
# win_by_wickets                                      0
# player_of_match                             JJ Bumrah
# venue              Rajiv Gandhi Intl. Cricket Stadium
# umpire1                                   Nitin Menon
# umpire2                                     Ian Gould
# ...

# %%
#INSIGHT
. Winner team toss by Mumbai Indians
.Wineer by matches Mumabi Indians
.Matches win by 1 runs foe Mumbai Indians
.Match was very closed

# %%
#iv.aMatch won by minimum wickets
matches['win_by_wickets'].min
# Out:
# <bound method Series.min of 0       0
# 1       7
# 2      10
# 3       6
# 4       0
#        ..
# 751     9
# 752     6
# 753     2
# 754     6
# 755     0
# Name: win_by_wickets, Length: 756, dtype: int64>

# %%
#INSIGHT
.Match finished in the last moments
.High match tension and excitement
.Chasing team had very few wickets left
.This match was a very closed match

# %%
#v.Matches  where D|L method was and wasn't applied
matches.dl_applied.value_counts()
# Out:
# dl_applied
# 0    737
# 1     19
# Name: count, dtype: int64

# %%
#INSIGHT
.Most IPL matches were played without the D|L methody
.Only few matches used D|L method due to rain
.Only a small number of matches used the D|L method

# %%
#GRAPH
import matplotlib.pyplot as plt

matches['dl_applied'].value_counts().plot(kind
    = 'bar')
plt.show()

# %%
#vi.Number of matches held in each city
matches['city'].value_counts()
# Out:
# city
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
#INSIGHT
.IPL matches are played in many different cities
.Some cities hosr more matches than other
.Big cricket cities usally hve higher number of matches

# %%
#vii.Number of matches won by each team 
matches['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
#INSIGHT
.Some trams have won more matches than other
.These teams show better overall performance in IPL
.Team with more wins are usally strong and consistent

# %%
#GRAPH
import matplotlib.pyplot as plt
matches['winner'].value_counts().plot(kind='bar')
plt.show()

# %%
#viii. Number of matches held every season 
matches['season'].value_counts()
# Out:
# season
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2018    60
# 2019    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: count, dtype: int64

# %%
#INSIGHT
.IPL is palyed evert in different season
.The number of matches change in some season
.Some seasons had more teams and more matches

# %%
#GRAPH
import matplotlib.pyplot as plt
matches['season'].value_counts().plot(kind='line')
plt.show()

# %%
#ix.Top 10 players based on number of Man of the Match awards
matches['player_of_match'].value_counts().head(10)
# Out:
# player_of_match
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# MEK Hussey        12
# Name: count, dtype: int64

# %%
#INSIGHT
.Some players win Man of the Match many times
.These players perform very well in matches
.They play an important role in their team's victory

# %%
#GRAPH
import matplotlib.pyplot as plt
matches['player_of_match'].value_counts().head(10).plot(kind='pie')
plt.show()

# %%
#x.Does winning the toss mean winning the match?
(matches['toss_winner']==
 matches['winner']).value_counts()
# Out:
# True     393
# False    363
# Name: count, dtype: int64

# %%
#INSIGHT
.Winning the toss doe not guarantee winning the match
.Match result mainly depends on team performance

# %%
#GRAPH
(matches['toss_winner']==
 matches['winner']).value_counts().plot(kind='bar')
plt.show()

# %%
#xi.What decisin was taken by capitan when they won the toss?
matches['toss_decision'].value_counts()
# Out:
# toss_decision
# field    463
# bat      293
# Name: count, dtype: int64

# %%
#INSIGHT
.Captains ususally choose fielding after winning the toss
.Some capitan choose batting first
.The decision depends on pitch condition and macth strategy

# %%
#xii.Number of matches where D|L method was pplied every season
dl_matches=matches[matches['dl_applied']==
    1]
dl_matches['season'].value_counts()
# Out:
# season
# 2016    4
# 2009    3
# 2011    3
# 2018    3
# 2008    2
# 2015    2
# 2017    1
# 2014    1
# Name: count, dtype: int64

# %%
#INSIGHT
.D|L nethod was used in some seasons due to rain
.Only few matches were affected by weather
.Most matches were played normally by without D|L method

# %%
#xiii. 
matches['result'].value_counts()
# Out:
# result
# normal       743
# tie            9
# no result      4
# Name: count, dtype: int64

# %%
#INSIGHT
.IPL matches mostly end with normal results
.Few matches end in tie or no result

# %%
#GRAPH
import matplotlib.pyplot as plt
matches['result'].value_counts().plot(kind='line')
plt.show()

# %%
#xiv.How mant times did a team win the loss
matches['toss_winner'].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Delhi Daredevils               80
# Rajasthan Royals               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: count, dtype: int64

# %%
#INSIGHT
.Some teams win the toss more times
.Toss plays an important role in match strategy

# %%
#GRAPHS
import matplotlib.pyplot as plt
matches['toss_winner'].value_counts().plot(kind='bar')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#xv.Best venue for defending and chasing
matches.groupby('venue')['winner'].count()
# Out:
# venue
# ACA-VDCA Stadium                                         2
# Barabati Stadium                                         7
# Brabourne Stadium                                       11
# Buffalo Park                                             3
# De Beers Diamond Oval                                    3
# Dr DY Patil Sports Academy                              17
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     11
# Dubai International Cricket Stadium                      7
# Eden Gardens                                            77
# Feroz Shah Kotla                                        66
# Feroz Shah Kotla Ground                                  7
# Green Park                                               4
# Himachal Pradesh Cricket Association Stadium             9
# Holkar Cricket Stadium                                   9
# IS Bindra Stadium                                        7
# JSCA International Stadium Complex                       7
# ...

# %%
#INSIGHT
.Some stadium hot more matches than other
.Pitch condition affect defending or chasing totals

# %%
#GRAPHS
matches['venue'].value_counts().head(10).plot(kind='bar')
plt.show()

# %%
#xvi.Best defending and chasing teams
matches['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
#INSIGHT
.Some teams are strong in defending totals
.Some teams perform better while chasing target

# %%
#xvii. Number of matches played in different stadium
matches['venue'].value_counts()
# Out:
# venue
# Eden Gardens                                            77
# M Chinnaswamy Stadium                                   73
# Wankhede Stadium                                        73
# Feroz Shah Kotla                                        67
# Rajiv Gandhi International Stadium, Uppal               56
# MA Chidambaram Stadium, Chepauk                         49
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Maharashtra Cricket Association Stadium                 21
# Subrata Roy Sahara Stadium                              17
# Dr DY Patil Sports Academy                              17
# Kingsmead                                               15
# Punjab Cricket Association IS Bindra Stadium, Mohali    14
# SuperSport Park                                         12
# Sardar Patel Stadium, Motera                            12
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     11
# ...

# %%
#INSIGHT
.IPL matches are played in many stadiums across india
.Some stadiums host mmore matches due to ptpularity

# %%
#GRAPH
import matplotlib.pyplot as plt
matches['venue'].value_counts().head(10).plot(kind='bar')
plt.show()
